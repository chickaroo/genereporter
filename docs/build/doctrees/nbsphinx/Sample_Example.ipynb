# %% [markdown]
# # Using Sample-Level Pipeline
#
# ## A sample-level (patient-level) visualization of the gene and cell-type of interest.

# %%
import sys
sys.path.append('/Users/samibening/Projects/genereporter/')
from genereporter.sample_pipeline import SamplePipeline
sp = SamplePipeline(wdir="/Users/samibening/Projects/genereporter/", adata="data/output/adata.h5ad")

# %%
GOI = 'VAV3'

# %%
sp.pl_violin(GOI)

# %%
sp.pl_sample_celltype(GOI)

# %%
sp.pl_violin(GOI, celltype='B Cell')
