# %%
import numpy as np
import pandas as pd
import anndata
# %matplotlib inline
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

# %%
adata = anndata.read_h5ad("C:/Users/saman/00_Bachelorarbeit/Bachelor/data/output/adata_norms.h5ad") # after QC before norm. 
df_all = adata.to_df(layer='tc_norm_log')

# %%
df = df_all.sample(n=30, axis='columns', random_state=1).astype(int)
df = df.sample(n=5000, axis='index', random_state=2)
df
# Out:
# index                         MFSD10  HMGCS2  CH17-340M24.3  CNN2  ORC6  \
# CID006515-1-ATGGATCAGGTAGACC       0       0              0     0     0
# CID008474-1-TTTCAGTGTCCTGTTC       0       0              0     0     0
# CID008474-1-AGGGAGTAGCTGGTGA       0       0              0     0     0
# CID007664-1-AGTTCCCCATAAGCGG       0       0              0     0     0
# CID007827-1-GCCATTCGTACTCAAC       0       0              0     0     0
# ...                              ...     ...            ...   ...   ...
# CID005217-1-CGCATGGAGTCACTAC       0       1              0     0     0
# CID008474-1-TCGACGGTCGCCTCTA       0       2              0     0     0
# CID006515-1-AAAGGTACAACGGCTC       0       0              0     0     0
# CID008474-1-TTAGGCAGTGAGCCAA       0       0              0     0     0
# CID006515-1-ATCTCTAGTCCAGTTA       0       0              0     0     0
#
# index                         BUB1B  NELFE  FANCG  SH3PXD2A  EXOC4  ...  \
# ...

# %%
ProfileReport(df, title="Profiling Report")

# %%
# look at distribution
def plot_hist(df):
    hist, edges = np.histogram(df, bins=int(np.max(df.values)))

    plt.figure()

    plt.bar(edges[:-1], hist, width = 0.5, color='#0504aa')
    plt.xlim(min(edges), 50)
    #plt.ylim(0, len(df)*2)
    plt.grid(axis='y', alpha=0.75)
    plt.xlabel('Gene Expression',fontsize=15)
    plt.ylabel('Frequency',fontsize=15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.show()

# %%
plot_hist(adata.to_df(layer='tc_norm'))
