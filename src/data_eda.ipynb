# %%
import numpy as np
import pandas as pd
import anndata
# %matplotlib inline
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

# %%
adata = anndata.read_h5ad("C:/Users/saman/00_Bachelorarbeit/Bachelor/data/output/adata_norms.h5ad") # after QC before norm. 
df_all = adata.to_df(layer='tc_norm_log')

# %%
df = df_all.sample(n=20, axis='columns', random_state=1).astype(int)
#df = df.sample(n=5000, axis='index', random_state=2)
df
# Out:
# index                         MFSD10  HMGCS2  CH17-340M24.3  CNN2  ORC6  \
# CID005217-1-AAAGGTAAGAGTCAGC       0       0              0     1     0
# CID005217-1-AAAGTCCTCGAACGGA       0       0              0     0     1
# CID005217-1-AACAGGGAGTATTGCC       1       0              0     0     0
# CID005217-1-AACAGGGGTGAATGAT       0       0              0     1     0
# CID005217-1-AACCAACGTCATCGCG       0       0              0     1     0
# ...                              ...     ...            ...   ...   ...
# CID008474-1-TTTGGTTTCCGAACGC       0       1              0     0     0
# CID008474-1-TTTGGTTTCTGCGGGT       0       0              0     0     0
# CID008474-1-TTTGTTGAGTTACTCG       0       1              0     0     0
# CID008474-1-TTTGTTGCATGAGTAA       0       0              0     0     0
# CID008474-1-TTTGTTGGTCTGTAAC       0       1              0     0     0
#
# index                         BUB1B  NELFE  FANCG  SH3PXD2A  EXOC4  CEBPZOS  \
# ...

# %%
ProfileReport(df, title="Profiling Report")
